# %%
import deeplabcut
from deeplabcut.pose_estimation_tensorflow.config import load_config
from deeplabcut.pose_estimation_tensorflow.nnets.utils import get_batch_spec
from deeplabcut.pose_estimation_tensorflow.core.train import setup_preloading
from deeplabcut.pose_estimation_tensorflow.nnets import PoseNetFactory

config_yaml = "C:\\Users\\User\\Documents\\CAS\\Ex_jobb\\BONDEN5-mathan-2022-03-14\\dlc-models\\iteration-0\\BONDEN5Mar14-trainset95shuffle1\\train\\pose_cfg.yaml"
cfg = load_config(config_yaml)
batch_spec = get_batch_spec(cfg)
batch, enqueue_op, placeholders = setup_preloading(batch_spec)

losses = PoseNetFactory.create(cfg).train(batch)

print("done")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
#       9 batch_spec = get_batch_spec(cfg)
#      10 batch, enqueue_op, placeholders = setup_preloading(batch_spec)
# ---> 12 losses = PoseNetFactory.create(cfg).train(batch)
#      14 print("done")
#
# File ~\Documents\GitHub\Seabird_Master_Thesis\DeepLabCut\deeplabcut\pose_estimation_tensorflow\nnets\base.py:22, in BasePoseNet.train(self, batch)
#      21 def train(self, batch):
# ---> 22     heads = self.get_net(batch[Batch.inputs])
#      23     if self.cfg["weigh_part_predictions"]:
#      24         part_score_weights = batch[Batch.part_score_weights]
#
# File ~\Documents\GitHub\Seabird_Master_Thesis\DeepLabCut\deeplabcut\pose_estimation_tensorflow\nnets\resnet.py:76, in PoseResnet.get_net(self, inputs)
#      75 def get_net(self, inputs):
# ...

# %%
from deeplabcut.utils import auxiliaryfunctions
config_yaml = "C:\\Users\\User\\Documents\\CAS\\Ex_jobb\\BONDEN5-mathan-2022-03-14\\dlc-models\\iteration-0\\BONDEN5Mar14-trainset95shuffle1\\train\\pose_cfg.yaml"
cfg = auxiliaryfunctions.read_config(config_yaml)
print("done")
# Out:
# done
